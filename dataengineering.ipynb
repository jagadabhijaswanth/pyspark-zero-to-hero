# %% [markdown]
# <a href="https://colab.research.google.com/github/jagadabhijaswanth/pyspark-zero-to-hero/blob/master/dataengineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/archive/cards_data.csv')
data
# Out:
#         id  client_id  card_brand        card_type       card_number  expires  \
# 0     4524        825        Visa            Debit  4344676511950444  12/2022
# 1     2731        825        Visa            Debit  4956965974959986  12/2020
# 2     3701        825        Visa            Debit  4582313478255491  02/2024
# 3       42        825        Visa           Credit  4879494103069057  08/2024
# 4     4659        825  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
# ...    ...        ...         ...              ...               ...      ...
# 6141  5361        185        Amex           Credit   300609782832003  01/2024
# 6142  2711        185        Visa           Credit  4718517475996018  01/2021
# 6143  1305       1007  Mastercard           Credit  5929512204765914  08/2020
# 6144   743       1110  Mastercard            Debit  5589768928167462  01/2020
# 6145  3199       1110        Visa           Credit  4994011318343994  12/2020
#
# ...

# %%
from pyspark.sql import SparkSession
spark = (
    SparkSession
    .builder
    .appName("Basic Transformation")
    .master("local[*]")
    .getOrCreate()
)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ecd3b5380ab3:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Basic Transformation - I</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # A CSV dataset is pointed to by path.
# # The path can be either a single CSV file or a directory of CSV files
# path = "examples/src/main/resources/people.csv"
#
# df = spark.read.csv(path)
# df.show()
#
# # Read a csv with delimiter, the default delimiter is ","
# df2 = spark.read.option("delimiter", ";").csv(path)
# df2.show()
# # +-----+---+---------+
# # |  _c0|_c1|      _c2|
# # +-----+---+---------+
# # | name|age|      job|
# # |Jorge| 30|Developer|
# # |  Bob| 32|Developer|
# # +-----+---+---------+
#
# # Read a csv with delimiter and a header
# df3 = spark.read.option("delimiter", ";").option("header", True).csv(path)
# df3.show()
# # +-----+---+---------+
# # | name|age|      job|
# # +-----+---+---------+
# # |Jorge| 30|Developer|
# # |  Bob| 32|Developer|
# # +-----+---+---------+
#
# # You can also use options() to use multiple options
# df4 = spark.read.options(delimiter=";", header=True).csv(path)
#
# # "output" is a folder which contains multiple csv files and a _SUCCESS file.
# df3.write.csv("output")
#
# # Read all files in a folder, please make sure only CSV files should present in the folder.
# folderPath = "examples/src/main/resources"
# df5 = spark.read.csv(folderPath)
# df5.show()
# # Wrong schema because non-CSV files are read
# # +-----------+
# # |        _c0|
# # +-----------+
# # |238val_238|
# # |  86val_86|
# # |311val_311|
# # |  27val_27|
# # |165val_165|
# +-----------+

# %%
df = spark.read.option('header',True).csv("/content/drive/MyDrive/archive/cards_data.csv")
df.show()
# Out:
# +----+---------+----------+---------------+----------------+-------+---+--------+----------------+------------+--------------+---------------------+----------------+
# |  id|client_id|card_brand|      card_type|     card_number|expires|cvv|has_chip|num_cards_issued|credit_limit|acct_open_date|year_pin_last_changed|card_on_dark_web|
# +----+---------+----------+---------------+----------------+-------+---+--------+----------------+------------+--------------+---------------------+----------------+
# |4524|      825|      Visa|          Debit|4344676511950444|12/2022|623|     YES|               2|      $24295|       09/2002|                 2008|              No|
# |2731|      825|      Visa|          Debit|4956965974959986|12/2020|393|     YES|               2|      $21968|       04/2014|                 2014|              No|
# ...

# %%
# SELECT columns
# select client_id,card_brand, czrd_type, credit_limit from emp

client_filter = df.select(df.client_id,df.card_brand,df.card_type,df.credit_limit)
client_filter.show()
# Out:
# +---------+----------+---------------+------------+
# |client_id|card_brand|      card_type|credit_limit|
# +---------+----------+---------------+------------+
# |      825|      Visa|          Debit|      $24295|
# |      825|      Visa|          Debit|      $21968|
# |      825|      Visa|          Debit|      $46414|
# |      825|      Visa|         Credit|      $12400|
# |      825|Mastercard|Debit (Prepaid)|         $28|
# |     1746|      Visa|         Credit|      $27500|
# |     1746|      Visa|          Debit|      $28508|
# |     1746|Mastercard|          Debit|       $9022|
# |     1746|Mastercard|Debit (Prepaid)|         $54|
# |     1746|Mastercard|Debit (Prepaid)|         $99|
# |     1718|Mastercard|          Debit|      $31599|
# |     1718|Mastercard|          Debit|      $27480|
# |     1718|Mastercard|          Debit|      $26743|
# |     1718|      Visa|          Debit|      $31463|
# |     1718|Mastercard|          Debit|      $16055|
# ...

# %%
# Using expr for select
# select card_id as c_id, name, cast(age as int) as age, salary from emp_filtered
